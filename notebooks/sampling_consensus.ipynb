# %% [markdown]
# ## Importing

# %%
import pandas as pd
import scipy as sp
import numpy as np

import emcee
from multiprocessing import Pool

import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
from matplotlib import font_manager
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import ListedColormap
from cycler import cycler
import corner
from typing import Any, Dict, List, Optional, Tuple, Union

import lymph

# %% [markdown]
# To do:
# Sampling mit ultimate truth consensus.

# %% [markdown]
# ## Creating or Loading Model

# %%
filename = "../data/extended_system.hdf5"

graph = {
    ('tumor', 'primary'): ['I', 'II', 'III', 'IV', 'V', 'VII'],
    ('lnl', 'I'): [],
    ('lnl', 'II'): ['I', 'III', 'V', 'VII'],
    ('lnl', 'III'): ['IV'],
    ('lnl', 'IV'): [],
    ('lnl', 'V'): [],
    ('lnl', 'VII'): [],
}
extended_systm = lymph.Unilateral(graph=graph)


print(extended_systm)
# Out:
# Unilateral lymphatic system with 1 tumor(s) and 6 LNL(s).
# primary-0.0%->I primary-0.0%->II primary-0.0%->III primary-0.0%->IV primary-0.0%->V primary-0.0%->VII II-0.0%->I II-0.0%->III II-0.0%->V II-0.0%->VII III-0.0%->IV

# %% [markdown]
# ## Modalities

# %%
spsn = {"PET": [0.86, 0.79],
        "MRI": [0.63, 0.81],
        "diagnostic_consensus": [0.63, 0.81],
        "pathology": [1., 1.]}
#                         ^   ^
#                specificty   sensitivity
extended_systm.modalities = spsn

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("../data/latest.csv", header=[0,1,2] )
t_stage = data.iloc[:,18]
data = data.iloc[:,21:168]
ipsi_data = data.xs("ipsi",level=1,axis=1)
t_stage.loc[t_stage <= 2, ] = "early"
t_stage.loc[t_stage!="early", ] = "late"


ipsi_data["info","t_stage"]= t_stage
ipsi_data = ipsi_data.drop(['Ia', 'Ib',"IIa","IIb"], level=1, axis=1)
ipsi_data = ipsi_data.drop(['CT', 'FNA',"pCT"], level=0, axis=1)

ipsi_data.to_csv("../data/ipsi_data.csv", index=False)

extended_systm.patient_data = ipsi_data
# Out:
# C:\Users\Luca\AppData\Local\Temp\ipykernel_25880\1607458719.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipsi_data["info","t_stage"]= t_stage
# Loading patients of late T-stage
# 100%|██████████| 14336/14336 [00:12<00:00, 1132.03it/s]
# Loading patients of early T-stage
# 100%|██████████| 20864/20864 [00:18<00:00, 1150.99it/s]

# %% [markdown]
# ## Storage of model

# %%
extended_systm.to_hdf(
    filename=filename, 
    name="extended/model"
)
# Out:
# C:\Users\Luca\anaconda3\envs\lymph2\lib\site-packages\lymph\utils.py:268: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->MultiIndex([(                 'MRI',       'I'),
#             (                 'MRI',      'II'),
#             (                 'MRI',     'III'),
#             (                 'MRI',      'IV'),
#             (                 'MRI',       'V'),
#             (                 'MRI',     'VII'),
#             (                 'PET',       'I'),
#             (                 'PET',      'II'),
#             (                 'PET',     'III'),
#             (                 'PET',      'IV'),
#             (                 'PET',       'V'),
#             (                 'PET',     'VII'),
#             ('diagnostic_consensus',       'I'),
#             ('diagnostic_consensus',      'II'),
#             ('diagnostic_consensus',     'III'),
#             ('diagnostic_consensus',      'IV'),
#             ('diagnostic_consensus',       'V'),
#             ('diagnostic_consensus',     'VII'),
#             (           'pathology',       'I'),
#             (           'pathology',      'II'),
#             (           'pathology',     'III'),
#             (           'pathology',      'IV'),
#             (           'pathology',       'V'),
#             (           'pathology',     'VII'),
#             (                'info', 't_stage')],
#            )]
#
#   store.put(

# %% [markdown]
# ## Likelihood

# %%
#settings for the binom distributions
early_p=0.3
max_t=10
t = np.arange(max_t + 1)

def llh(theta):
    spread_probs, late_p = theta[:-1], theta[-1]
    
    print("run")
    if late_p > 1. or late_p < 0.:
        return -np.inf
    
    
    time_dists={
        "early": sp.stats.binom.pmf(t, max_t, early_p),
        "late" : sp.stats.binom.pmf(t, max_t, late_p),
    }
     
    return extended_systm.marginal_log_likelihood(spread_probs, t_stages=["early", "late"], time_dists=time_dists)

# %% [markdown]
# ## Sampling

# %%
# Settings for the sampler
ndim = len(extended_systm.spread_probs) + 1
nwalkers = 20 * ndim
nstep = 10000
burnin = 5000
moves = [(emcee.moves.DEMove(), 0.8), (emcee.moves.DESnookerMove(), 0.2)]


#prepare the backend
new_backend = emcee.backends.HDFBackend(
    filename=filename,
    name="extended/samples"
)
#backend.reset(nwalkers, ndim)
print("Initial size: {0}".format(new_backend.iteration))

# starting point
initial_spread_probs = np.random.uniform(low=0., high=1., size=(nwalkers,ndim))


if __name__ == "__main__":
    sampler = emcee.EnsembleSampler(
        nwalkers, ndim, 
        llh, 
        moves=moves,
        backend=new_backend
    )
    sampler.run_mcmc(initial_spread_probs, nstep-new_backend.iteration, progress=True)
    samples_HMM = sampler.get_chain(flat=True, discard=burnin)
    print(samples_HMM)
# Out:
# Initial size: 5161
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 0/4839 [00:00<?, ?it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 1/4839 [00:00<31:46,  2.54it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 2/4839 [00:00<30:34,  2.64it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 3/4839 [00:01<30:35,  2.63it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 4/4839 [00:02<54:54,  1.47it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 5/4839 [00:02<50:52,  1.58it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 6/4839 [00:03<46:47,  1.72it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 7/4839 [00:03<43:58,  1.83it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 8/4839 [00:04<43:39,  1.84it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 9/4839 [00:04<43:58,  1.83it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 10/4839 [00:06<1:00:30,  1.33it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 11/4839 [00:07<1:13:31,  1.09it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 12/4839 [00:08<1:11:37,  1.12it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 13/4839 [00:08<1:07:48,  1.19it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 14/4839 [00:10<1:20:35,  1.00s/it]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 15/4839 [00:11<1:18:30,  1.02it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 16/4839 [00:12<1:15:53,  1.06it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 17/4839 [00:12<1:12:46,  1.10it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 18/4839 [00:13<1:10:08,  1.15it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 19/4839 [00:14<1:07:09,  1.20it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 20/4839 [00:15<1:05:21,  1.23it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
#   0%|          | 21/4839 [00:15<1:03:21,  1.27it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# Traceback (most recent call last):
#   File "C:\Users\Luca\anaconda3\envs\lymph2\lib\site-packages\emcee\ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "C:\Users\Luca\AppData\Local\Temp\ipykernel_25880\1399224823.py", line 15, in llh
#     "early": sp.stats.binom.pmf(t, max_t, early_p),
#   File "C:\Users\Luca\anaconda3\envs\lymph2\lib\site-packages\scipy\stats\_distn_infrastructure.py", line 3178, in pmf
#     cond1 = (k >= _a) & (k <= _b) & self._nonzero(k, *args)
#   File "C:\Users\Luca\anaconda3\envs\lymph2\lib\site-packages\scipy\stats\_distn_infrastructure.py", line 3102, in _nonzero
#     return floor(k) == k
# KeyboardInterrupt
#   0%|          | 21/4839 [00:16<1:01:56,  1.30it/s]
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# run
# emcee: Exception while calling your likelihood function:
#   params: [0.46907693 0.73040578 0.22127444 0.16114741 0.24413941 0.01446518
#  0.01969153 0.5043818  0.43468537 0.08164742 1.01886673 0.22065085]
#   args: []
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Luca\lymph_notebooks\notebooks\sampling.ipynb Cell 14' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=20'>21</a> if __name__ == "__main__":
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=21'>22</a>     sampler = emcee.EnsembleSampler(
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=22'>23</a>         nwalkers, ndim,
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=23'>24</a>         llh,
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=24'>25</a>         moves=moves,
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=25'>26</a>         backend=new_backend
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=26'>27</a>     )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=27'>28</a>     sampler.run_mcmc(initial_spread_probs, nstep-new_backend.iteration, progress=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=28'>29</a>     samples_HMM = sampler.get_chain(flat=True, discard=burnin)
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000013?line=29'>30</a>     print(samples_HMM)
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\emcee\ensemble.py:443, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=439'>440</a>     initial_state = self._previous_state
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=441'>442</a> results = None
# --> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=442'>443</a> for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=443'>444</a>     pass
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=445'>446</a> # Store so that the ``initial_state=None`` case will work
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\emcee\ensemble.py:402, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=398'>399</a> move = self._random.choice(self._moves, p=self._weights)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=400'>401</a> # Propose
# --> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=401'>402</a> state, accepted = move.propose(model, state)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=402'>403</a> state.random_state = self.random_state
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=404'>405</a> if tune:
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\emcee\moves\red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=89'>90</a> q, factors = self.get_proposal(s, c, model.random)
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=91'>92</a> # Compute the lnprobs of the proposed position.
# ---> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=92'>93</a> new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=94'>95</a> # Loop over the walkers and update them accordingly.
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=95'>96</a> for i, (j, f, nlp) in enumerate(
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=96'>97</a>     zip(all_inds[S1], factors, new_log_probs)
#      <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/moves/red_blue.py?line=97'>98</a> ):
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\emcee\ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=486'>487</a>     else:
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=487'>488</a>         map_func = map
# --> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=488'>489</a>     results = list(map_func(self.log_prob_fn, p))
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=490'>491</a> try:
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=491'>492</a>     log_prob = np.array([float(l[0]) for l in results])
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\emcee\ensemble.py:624, in _FunctionWrapper.__call__(self, x)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=621'>622</a> def __call__(self, x):
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=622'>623</a>     try:
# --> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=623'>624</a>         return self.f(x, *self.args, **self.kwargs)
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=624'>625</a>     except:  # pragma: no cover
#     <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/emcee/ensemble.py?line=625'>626</a>         import traceback
#
# c:\Users\Luca\lymph_notebooks\notebooks\sampling.ipynb Cell 12' in llh(theta)
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=9'>10</a> if late_p > 1. or late_p < 0.:
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=10'>11</a>     return -np.inf
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=13'>14</a> time_dists={
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=14'>15</a>     "early": sp.stats.binom.pmf(t, max_t, early_p),
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=15'>16</a>     "late" : sp.stats.binom.pmf(t, max_t, late_p),
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=16'>17</a> }
#      <a href='vscode-notebook-cell:/c%3A/Users/Luca/lymph_notebooks/notebooks/sampling.ipynb#ch0000011?line=18'>19</a> return extended_systm.marginal_log_likelihood(spread_probs, t_stages=["early", "late"], time_dists=time_dists)
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\scipy\stats\_distn_infrastructure.py:3178, in rv_discrete.pmf(self, k, *args, **kwds)
#    <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3175'>3176</a> k = asarray((k-loc))
#    <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3176'>3177</a> cond0 = self._argcheck(*args)
# -> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3177'>3178</a> cond1 = (k >= _a) & (k <= _b) & self._nonzero(k, *args)
#    <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3178'>3179</a> cond = cond0 & cond1
#    <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3179'>3180</a> output = zeros(shape(cond), 'd')
#
# File ~\anaconda3\envs\lymph2\lib\site-packages\scipy\stats\_distn_infrastructure.py:3102, in rv_discrete._nonzero(self, k, *args)
#    <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3100'>3101</a> def _nonzero(self, k, *args):
# -> <a href='file:///c%3A/Users/Luca/anaconda3/envs/lymph2/lib/site-packages/scipy/stats/_distn_infrastructure.py?line=3101'>3102</a>     return floor(k) == k
#
# KeyboardInterrupt:
